# %%
# intersection code because I already wrote the quadratic code in lab1

start = 0
stop = 10

a = 5
b = 10
c = 20
d = 5
function findintersection(a, b, c, d)
    if a == c
        error("parallel lines!")
    end
    intersection = b - d / c - a
end

findintersection(a, b, c, d)
# Out:
# 4.75

# %%
findintersection(5, b, 5, d)
# Out:
# parallel lines!
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] findintersection(a::Int64, b::Int64, c::Int64, d::Int64)
#
#    @ Main ~/COSMOS.jl/lab2.ipynb:12
#
#  [3] top-level scope
#
#    @ ~/COSMOS.jl/lab2.ipynb:1

# %%
# extra 2 
# This finds square roots based on an iterative process

x = 1
A = 25


for j in 1:20
   x = x/2 + A/(2x)
   print(j)
   print(" ")
   println(x)
end
# Out:
# 1
# 13.0
# 2 7.461538461538462
# 3 5.406026962727994
# 4 5.015247601944898
# 5 5.000023178253949
# 6 5.000000000053722
# 7 5.0
# 8 5.0
# 9 5.0
# 10 5.0
# 11 5.0
# 12 5.0
# 13 5.0
# 14 5.0
# 15 5.0
# 16 5.0
# 17 5.0
# 18 5.0
# 19 5.0
# 20 5.0

# %%
# extra 3
# This algorithm finds cube roots through an iterative process
x = 1
A = 125

for j in 1:20
    x = 2x/3 + A/(3x^2)
    print(j)
    print(" ")
    println(x)
end
# Out:
# 1 42.33333333333333
# 2 28.24547226872231
# 3 18.882541364436875
# 4 12.705221444241388
# 5 8.728269189040267
# 6 6.365777068939238
# 7 5.272071048468867
# 8 5.013799001275562
# 9 5.000037942835659
# 10 5.000000000287929
# 11 5.0
# 12 5.0
# 13 5.0
# 14 5.0
# 15 5.0
# 16 5.0
# 17 5.0
# 18 5.0
# 19 5.0
# 20 5.0

# %%
# extra 3.5
# This algorithm finds 5th roots through an iterative process

x = 1
A = 3125

for j in 1:50
    x = 4x/5 + A/(5x^4)
    print(j)
    print(" ")
    println(x)
end
# Out:
# 1 625.8
# 2 500.6400000040751
# 3 400.51200001320905
# 4 320.40960003485674
# 5 256.3276800871858
# 6 205.0621442145251
# 7 164.04971572507824
# 8 131.2397734429976
# 9 104.99182086117295
# 10 83.9934618324313
# 11 67.19478202329772
# 12 53.7558562762146
# 13 43.004759868399624
# 14 34.40399062642594
# 15 27.523638613992464
# 16 22.019999963287237
# 17 17.618658312071602
# 18 14.101412824997999
# 19 11.296936534125187
# 20 9.0759232441321
# 21 7.352850711488244
# 22 6.0961048519202174
# 23 5.329437773947717
# 24 5.038287462882173
# 25 5.000577510531793
# 26 5.000000133376554
# 27 5.000000000000007
# 28 5.0
# 29 5.0
# 30 5.0
# 31 5.0
# 32 5.0
# 33 5.0
# 34 5.0
# 35 5.0
# 36 5.0
# 37 5.0
# 38 5.0
# 39 5.0
# 40 5.0
# 41 5.0
# 42 5.0
# 43 5.0
# 44 5.0
# 45 5.0
# 46 5.0
# 47 5.0
# 48 5.0
# 49 5.0
# 50 5.0

# %%
# printing random values

using Random

Rows = 20
Columns = 1
seed = 12345

rng = MersenneTwister(seed)

w = randn!(rng, zeros(Rows, Columns))

print(w)
# Out:
# [1.1723579360378058
# ; 0.852707459143324; 0.4155652148774136; 0.5164248452398443; 0.6857588179217985; 0.2822721070914419; -1.4770833580140172; 0.1267470097964963; 1.4664657481875898; -0.15815767889698065; 0.6068081464438165; 2.0064460500174603; -0.5885084628263365; 0.0736438412423627; 1.9258483832944162; -1.304361241261331; 0.37835312304626906; 1.2165607674925232; 1.1287063420144976; -0.34152128061143205;;]

# %%
# moments
using Random

totalmoments = 5 # amount of items in momvec
N = 1000000 # try 1m later

function generatemoments(totalmoments, N) # making this in a function because of memory efficiency 
    seed = 12345
    rng = MersenneTwister(seed)

    momvec = zeros(Float64, 0) # the output vector. Will have items pushed onto it.
    momarr = randn(rng, Float64, (totalmoments, N)) # generates a 5x100 matrix of (pseudo)random values to calculate moments

    for i in 1:totalmoments

        moment = 0 # ensure everything is 0 before we start
        
        # the actual algorithm
        for j in 1:N
            moment += momarr[i,j]^i
        end
        moment = moment/N
        
        push!(momvec, moment) # append new value
    end

    return momvec
end

# @time generatemoments(totalmoments, N)

using Plots
gr()

histogram(generatemoments(totalmoments, N))

# %%
using Random

steps = 100000
bias = .5

position = 0

seed = 5431
Random.seed!(seed)
# rng = MersenneTwister(seed)

poshist = zeros(Float64, 0)
randhist = zeros(Float64, 0)

for i in 1:steps
    randval = rand()
    
    if randval > bias
        position += 1
    elseif randval < bias
        position -= 1
    end

    push!(randhist, randval)
    push!(poshist, position)
end

print(poshist[steps])

using Plots
gr()
histogram(poshist)

# CONCLUSION: THIS IS NOT A TRNG. THIS IS A PRNG. I am actually graphing the randomness of a function, as opposed to anything else.
# TLDR: My poor entropy :(
# Out:
# 234.0

# %%
using Random

steps = 100000000

seed = 5431
Random.seed!(seed)

randhist = zeros(Float64, 0)

for i in 1:steps
    randval = rand()

    push!(randhist, randval)
end


using Plots
gr()
histogram(randhist)

# CONCLUSION: THIS IS NOT A TRNG. THIS IS A PRNG. I am actually graphing the randomness of a function, as opposed to anything else.
# TLDR: My poor entropy :(
